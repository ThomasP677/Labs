# %%
import random


def my_and(left, right):
    if right:
        return left_boolean
    if left:
        return right_boolean
    else:
        return False

def my_or(left, right):
    if left:
        return True
    if right:
        return True
    else:
        return False

def boolean_about_a_string(string):
    return len(string) % 2 == 0

left_str = input('Please enter a string: ')
right_str = input('Please enter another one: ')

left_boolean = boolean_about_a_string(left_str)
right_boolean = boolean_about_a_string(right_str)

print()
print('My function is', left_boolean, 'for', "'" + left_str + "'")
print('and it is', right_boolean, 'for', "'" + right_str + "'")
print()

print(left_boolean, 'and', right_boolean, '==',
      my_and(left_boolean, right_boolean))

print(left_boolean, 'or', right_boolean, '==',
      my_or(left_boolean, right_boolean))




def get_coupon():
    coupon = random.randint(1, 10)
    return coupon

def get_coupons(clist):
    for i in range(10):
        clist.append(get_coupon())





# In this cell, keep on collecting coupons until you get all 10 coupons.
#
# Questions to consider:
# * How will you store your coupons?
# through a dictionary
# * How will you keep track of the number of unique coupons collected so far?
# It will be the variable in my dictionary
# * How will you keep track of total coupons collected?
# I will take the length of the dictionary





coupons = [] # The best match is a list.
get_coupons(coupons)
#How will you keep getting coupons until you collect the whole set of 10?
coupons_received = int(len(coupons)-1)

# Keep on receiving coupons until you have collected the whole set.
# This is what you would do for a single coupon:
one_to_ten =[1,2,3,4,5,6,7,9,10]
for i in one_to_ten:
    try:
        while one_to_ten[i] not in coupons:
            coupon = get_coupon()
            coupons_received = coupons_received + 1
            if coupon not in coupons:
                coupons.append(coupon)
    except:
        break

print(coupons)

#        Print out the total number of coupons received.
print('Number of coupons received:', coupons_received)
#        Print out your coupon collection.


flower_stock = ('roses', 'lavender', 'sunflowers', 'gardenias', 'orchids')


def process_shipment(shipment):
    inventory = {}
