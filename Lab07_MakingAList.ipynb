# %%
ef sorted_cities(city_names):
    city_list = []
    for i in range(len(city_names)):
        if city_names[i] == ",":
            city_list.append(city_names[0:i-1])

    city_list.sort()
    print(city_list)

def is_permutation(list1, list2):
    list1.sort()
    list2.sort()


    for i in range(len(list1)):
        if list1[i] == list2[i] and len(list1) == len(list2):
            continue
        else:
            return False
    return True


print(sorted_cities('San Francisco,Boston,Chicago,Indianapolis'))

def has_won(board, symbol):
    if symbol.lower() == 'x':
        for i in board:
            if board[0][0] == 'X' and board[1][0] == 'X' and board[2][0] == 'X':
                return True
            elif board[0][0] == 'X' and board[1][1] == 'X' and board[2][2] == 'X':
                return True
            elif board[0][0] == 'X' and board[0][1] == 'X' and board[0][2] == 'X':
                return True
            elif board[2][0] == 'X' and board[1][1] == 'X' and board[0][2] == 'X':
                return True
            elif board[2][0] == 'X' and board[2][1] == 'X' and board[2][2] == 'X':
                return True
            elif board[0][2] == 'X' and board[1][2] == 'X' and board[2][2] == 'X':
                return True

    if symbol.lower() == 'o':
        for i in board:
            if board[0][0] == 'O' and board[1][0] == 'O' and board[2][0] == 'O':
                return True
            elif board[0][0] == 'O' and board[1][1] == 'O' and board[2][2] == 'O':
                return True
            elif board[0][0] == 'O' and board[0][1] == 'O' and board[0][2] == 'O':
                return True
            elif board[2][0] == 'O' and board[1][1] == 'O' and board[0][2] == 'O':
                return True
            elif board[2][0] == 'O' and board[2][1] == 'O' and board[2][2] == 'O':
                return True
            elif board[0][2] == 'O' and board[1][2] == 'O' and board[2][2] == 'O':
                return True
    return False


print(is_permutation([1, 2, 3], [3, 1, 2]))
print(is_permutation([1, 1, 1, 2],[1, 2, 1, 1]))
print(is_permutation([1, 2, 3, 1], [1, 2, 3]))
print(is_permutation([1, 1, 2, 3], [1, 3, 2, 2]))


# TICK TAC TOE

x = 'X'
o = 'O'
empty = '_'

board = [['_', '_', '_'],
         ['_', '_', '_'],
         ['_', '_', '_']]
while True:
     player1x = int(input("Player 1 what is the x coordinate of your move: "))
     player1y = int(input("Player 1 what is the y coordinate of your move: "))
     board[player1x][player1y] = 'X'
     print(board)
     if has_won(board, x):
         print("player1 wins!!")
         break
     player2x = int(input("Player 2 what is the x coordinate of your move: "))
     player2y = int(input("Player 2 what is the y coordinate of your move: "))
     board[player2x][player2y] = 'O'
     print(board)
     if has_won(board, o):
         print("player2 wins!!")
         break
